# %% [markdown]
# # 1. Project Information
#
# ### Title: ***Data Visualisation Using Python***
# ### Student Name: ***Ashish Michael Chauhan***
# ### Roll Numbers: ***055007***
# ### Section K

# %% [markdown]
# # 2. Description of Data
# #### Data Source: Kaggle | Size: 2.55 MB
# #### Data Type: Panel
# #### Data Dimension: Number of Variables - 16 | Number of Observations - 15000
# #### Data Variable Type: Text - 12 | Number - 4 {Integer - 2 | Decimal - 2}
# #### Data Variable Category: Index - 1 | Categorical {Nominal - 10} | Non-Categorical - 5

# %% [markdown]
# # 3. Data Visualisastion

# %% [markdown]
# ## A.
#
# ![1-2.png](attachment:1-2.png)
#
#
#
# ### Objective of the Graph
#
# The objective of the graph is to visualize and compare the transaction values of different countries. It provides a clear representation of the relative standing of each country in terms of transactions.
#
# ### General Insights
# ####  Dominance of Bangladesh: Bangladesh stands out as the country with the highest transaction value, indicating its significant presence in the analyzed market or sector.
#
# #### India and Solomon Islands: India and Solomon Islands follow closely behind, suggesting they are also major players in the market.
#
# #### Wide Range of Transaction Values: The graph reveals a wide range of transaction values among the countries, with some countries having significantly higher or lower values compared to others.
#
# ### Managerial Insights
# #### Market Focus: The graph highlights the countries that are dominant in the market. Businesses can use this information to identify potential target markets or competitors.
#
# #### Competitive Analysis: Companies can compare their own transaction values to those of other countries to assess their market position and identify areas for improvement.
#
# #### Growth Opportunities: Countries with lower transaction values may represent untapped market opportunities. Businesses can explore strategies to expand their reach into these regions.
#
# #### Strategic Partnerships: The graph can help identify potential partners or collaborators in countries with high transaction values. Collaborating with these countries can provide access to new markets and resources.
#
# #### Risk Assessment: Countries with fluctuating transaction values may indicate market instability or uncertainty. Businesses can assess the risks associated with operating in these regions and develop contingency plans.

# %% [markdown]
# ## B.
#
# ![2.png](attachment:2.png)
#
# ### Objective of the Graph
# The objective of the graph is to visualize the trends of transaction values for different product categories over time. It provides a clear representation of how the transaction volumes for each category have evolved from April to October.
#
# ### General Insights
#
# #### Variability Across Categories: The graph shows significant fluctuations in transaction values across different categories. Some categories experience growth, while others decline during specific periods.
#
# #### Seasonal Patterns: There appear to be potential seasonal patterns in the data, especially for certain categories. For instance, the transaction values for clothing and toys might exhibit seasonal peaks or troughs.
#
# #### Correlation Between Categories: In some cases, there might be a correlation between the transaction values of different categories. For example, an increase in one category might be accompanied by a decrease in another.
#
# ### Managerial Insights
#
# #### Demand Forecasting: The graph can help businesses forecast future demand for their products by identifying trends and patterns in transaction values. This information can be used to optimize inventory levels and production planning.
#
# #### Promotional Strategies: By analyzing the seasonal patterns in transaction values, businesses can develop targeted promotional strategies to stimulate demand during periods of low sales.
#
# #### Product Mix Optimization: The graph can help businesses evaluate the performance of different product categories and identify areas for improvement. This information can be used to optimize the product mix and allocate resources more effectively.
#
# #### Competitive Analysis: By comparing the transaction trends of their own products to those of competitors, businesses can gain insights into market dynamics and identify opportunities for differentiation.
#
# #### Risk Management: The graph can help businesses identify potential risks associated with fluctuations in transaction values. This information can be used to develop contingency plans and mitigate risks.

# %% [markdown]
# ## C.
#
# ![3.png](attachment:3.png)
#
# ### Objective of the Graph
# The objective of the graph is to visualize the distribution of transaction values across different product categories. It provides a clear representation of the relative importance of each category in terms of total transaction value.
#
# ### General Insights
#
# #### Dominance of Toys: Toys are the leading category, accounting for 28.2% of the total transaction value. This suggests that toys are the most popular or high-value product category in the analyzed dataset.
#
# #### Clothing and Furniture: Clothing and furniture follow closely behind, indicating their significant contribution to the overall transaction value.
#
# #### Electronics and Machinery: Electronics and machinery have lower shares compared to the other categories, suggesting they might be less popular or have lower average transaction values.
#
# ### Managerial Insights
#
# #### Product Focus: The graph highlights the product categories that are driving the most revenue. Businesses can use this information to focus on promoting and expanding these categories.
#
# #### Product Mix Optimization: By analyzing the distribution of transaction values, businesses can assess the balance of their product mix and identify areas for improvement. For example, if a particular category is underperforming, businesses can consider introducing new products or implementing marketing strategies to boost sales.
#
# #### Market Segmentation: The graph can help businesses identify different market segments based on product preferences. This information can be used to tailor marketing campaigns and product offerings to specific customer groups.
#
# #### Pricing Strategy: By understanding the relative value of different categories, businesses can develop appropriate pricing strategies. For example, products in higher-value categories might be priced higher to reflect their perceived value.
#
# #### Resource Allocation: The graph can help businesses allocate resources more effectively by prioritizing categories with higher transaction values. This can involve investing in research and development, marketing, or inventory management for these categories.

# %% [markdown]
# ## D.
#
# ![4.png](attachment:4.png)
#
# ### Objective of the Graph
# The objective of the graph is to visualize the transaction values for different product categories across time periods. It provides a clear representation of how the performance of each category has evolved from February to December.
#
# ### General Insights
#
# #### Seasonal Patterns: The heatmap shows clear seasonal patterns in transaction values for certain categories. For example, clothing and toys might have higher sales during specific months, such as December.
#
# #### Category-Specific Trends: Each category exhibits unique trends over time. Some categories might experience consistent growth, while others may fluctuate or decline.
#
# #### Peak and Off-Peak Periods: The heatmap identifies peak and off-peak periods for different categories. Businesses can use this information to optimize inventory levels and marketing efforts.
#
# ### Managerial Insights
#
# #### Demand Forecasting: The heatmap can help businesses forecast future demand for their products by identifying seasonal patterns and category-specific trends. This information can be used to optimize inventory levels and production planning.
#
# #### Promotional Strategies: By analyzing the peak and off-peak periods, businesses can develop targeted promotional strategies to stimulate demand during slower times and capitalize on peak seasons.
#
# #### Product Mix Optimization: The heatmap can help businesses evaluate the performance of different product categories throughout the year. This information can be used to optimize the product mix and allocate resources more effectively.
#
# #### Competitive Analysis: By comparing the performance of their own products to that of competitors, businesses can gain insights into market dynamics and identify opportunities for differentiation.
#
# #### Risk Management: The heatmap can help businesses identify potential risks associated with fluctuations in transaction values. This information can be used to develop contingency plans and mitigate risks.

# %% [markdown]
# ## E.
#
# ![5.png](attachment:5.png)
#
# ### Objective of the Graph
# The objective of the graph is to visualize the cumulative transaction values for different product categories over time. It provides a clear representation of how the total transaction value for each category has evolved from February to December.
#
# ### General Insights
#
# #### Dominant Categories: Certain categories, such as clothing and electronics, have consistently contributed significantly to the cumulative transaction value throughout the year.
#
# #### Seasonal Fluctuations: The graph shows seasonal fluctuations in the cumulative transaction values for some categories. For example, toys and clothing might experience higher cumulative values during certain months.
#
# #### Growth and Decline: Some categories exhibit periods of growth, while others may experience decline in their cumulative transaction values.
#
# ### Managerial Insights
#
# #### Product Prioritization: The graph highlights the product categories that have contributed most to the overall business performance. Businesses can prioritize these categories for marketing, product development, and resource allocation.
#
# #### Seasonal Planning: By identifying seasonal patterns in cumulative transaction values, businesses can optimize inventory levels, staffing, and promotional activities to meet demand fluctuations.
#
# #### Product Mix Optimization: The graph can help businesses evaluate the performance of different product categories over time and identify areas for improvement. This information can be used to optimize the product mix and allocate resources more effectively.
#
# #### Competitive Analysis: By comparing the cumulative transaction values of their own products to those of competitors, businesses can gain insights into market dynamics and identify opportunities for differentiation.
#
# #### Risk Management: The graph can help businesses identify potential risks associated with fluctuations in transaction values. This information can be used to develop contingency plans and mitigate risks.

# %% [markdown]
# ## F.
#
# ![6.png](attachment:6.png)
#
# ### Objective of the Graph
# The objective of the graph is to visualize the distribution of transaction values across different product categories and countries. It provides a hierarchical representation of the relationships between categories and countries.
#
# ### General Insights
#
# #### Dominant Categories and Countries: The graph identifies the dominant categories and countries in terms of transaction value. For example, toys and clothing appear to be major categories, while India and Solomon Islands are prominent countries.
#
# #### Category-Country Relationships: The sunburst chart reveals the relationships between categories and countries. Some countries might specialize in certain categories, while others might have a more diversified product mix.
#
# #### Geographic Concentration: The graph can identify geographic concentrations of transactions. For instance, certain regions or countries might have a higher concentration of transactions in specific categories.
#
# ### Managerial Insights
#
# #### Market Segmentation: The graph can help businesses identify different market segments based on product categories and geographic regions. This information can be used to tailor marketing campaigns and product offerings to specific customer groups.
#
# #### Product Focus: Businesses can use the graph to identify their core product categories and countries. This information can help guide resource allocation and strategic planning.
#
# #### Expansion Opportunities: The graph can identify untapped markets or regions with potential for growth. Businesses can explore opportunities to expand their operations into these areas.
#
# #### Competitive Analysis: By comparing the performance of their own products and countries to that of competitors, businesses can gain insights into market dynamics and identify areas for differentiation.
#
# #### Risk Management: The graph can help businesses identify potential risks associated with geographic concentration or dependence on specific product categories. This information can be used to diversify their product portfolio and reduce risks.

# %% [markdown]
# ## G.
#
# ![7.png](attachment:7.png)
#
# ### Objective of the Graph
# The objective of the graph is to visualize the distribution of transaction values for each country. It provides a clear representation of the variability and range of transaction values within each country.
#
# ### General Insights
#
# #### Distribution Patterns: The violin plot reveals different distribution patterns for each country. Some countries have a more concentrated distribution of transaction values, while others exhibit a wider spread.
#
# #### Outliers: The graph identifies outliers, which are data points that significantly deviate from the main distribution. These outliers can be further investigated to understand their impact on overall transaction patterns.
#
# #### Country Comparisons: The violin plot allows for easy comparison of transaction value distributions across different countries. This can help identify countries with similar or dissimilar patterns.
#
# ### Managerial Insights
#
# #### Customer Segmentation: The graph can help businesses identify different customer segments within each country based on transaction values. This information can be used to tailor marketing campaigns and product offerings to specific customer groups.
#
# #### Pricing Strategy: By understanding the distribution of transaction values, businesses can develop appropriate pricing strategies for each country. For example, countries with a wider range of transaction values might require more differentiated pricing.
#
# #### Risk Assessment: The graph can help businesses identify potential risks associated with outliers or extreme transaction values. This information can be used to develop contingency plans and mitigate risks.
#
# #### Competitive Analysis: By comparing the distribution of transaction values across different countries, businesses can gain insights into competitive dynamics and identify opportunities for differentiation.
#
# #### Resource Allocation: The graph can help businesses allocate resources more effectively by understanding the distribution of transaction values within each country. For example, countries with a higher concentration of high-value transactions might warrant increased investment.

# %% [markdown]
# ## H.
#
# ![8.png](attachment:8.png)
#
# ### Objective of the Graph
# The objective of the graph is to visualize the distribution of transaction values for different shipping methods. It provides a clear representation of the variability and range of transaction values associated with each shipping method.
#
# ### General Insights
#
# #### Median Transaction Values: The median transaction value for land shipping is the highest, followed by sea and air shipping. This suggests that land shipping might be associated with higher-value transactions on average.
#
# #### Distribution Spread: The box plots show the spread of transaction values for each shipping method. Some shipping methods have a wider range of transaction values, indicating more variability.
#
# #### Outliers: The graph identifies outliers, which are data points that significantly deviate from the main distribution. These outliers can be further investigated to understand their impact on overall transaction patterns.
#
#
# ### Managerial Insights
# #### Shipping Cost Analysis: The graph can help businesses analyze the relationship between shipping method and transaction value. This information can be used to evaluate the cost-effectiveness of different shipping methods and identify opportunities for cost savings.
#
# #### Customer Preference Analysis: By understanding the distribution of transaction values for each shipping method, businesses can gain insights into customer preferences and offer shipping options that align with their needs.
#
# #### Risk Management: The graph can help businesses identify potential risks associated with outliers or extreme transaction values for specific shipping methods. This information can be used to develop contingency plans and mitigate risks.
#
# #### Supply Chain Optimization: The graph can provide insights into the factors that influence transaction values for different shipping methods. This information can be used to optimize the supply chain and reduce costs.
# #### Negotiation Strategies: The graph can help businesses negotiate better shipping rates with carriers by understanding the distribution of transaction values and identifying opportunities for volume discounts.
